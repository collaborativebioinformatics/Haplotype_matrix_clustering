# %%
import pandas numpy

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
pip install haptools

# %%
DEFNB_haps_table = pd.read_csv("DEFB1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.dedup_snps.haps",sep=" ",header=None)
DEFNB_haps_table
# look at just ID + pres/abs columns
select_columns = list([2])+list(range(5,5013))
# DEFNB_haps_table.iloc[:,[1,5:5012]]
DEFNB_haps_table_for_clustmap = DEFNB_haps_table.iloc[:,select_columns]
DEFNB_clustermap = sb.clustermap(DEFNB_haps_table_for_clustmap,vmin=0,vmax=1,method="single")
# DEFNB_clustermap.set_axis_labels(['Individual haplotype', 'Variant'])
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
sb.clustermap(DEFNB_haps_table_for_clustmap,vmin=0,vmax=1)

# %%
HLAA_haps_table = pd.read_csv("HLAA.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.dedup_snps.haps",sep=" ",header=None)
HLAA_haps_table
# look at just ID + pres/abs columns
select_columns = list([2])+list(range(5,5013))
# DEFNB_haps_table.iloc[:,[1,5:5012]]
HLAA_haps_table_for_clustmap = HLAA_haps_table.iloc[:,select_columns]
HLAA_clustermap = sb.clustermap(HLAA_haps_table_for_clustmap,vmin=0,vmax=1)
HLAA_clustermap
#HLAA_haps_table
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
TNF_haps_table = pd.read_csv("TNF.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.dedup_snps.haps",sep=" ",header=None)
TNF_haps_table
# look at just ID + pres/abs columns
select_columns = list([2])+list(range(5,5013))
# DEFNB_haps_table.iloc[:,[1,5:5012]]
TNF_haps_table_for_clustmap = TNF_haps_table.iloc[:,select_columns]
TNF_clustermap = sb.clustermap(TNF_haps_table_for_clustmap,vmin=0,vmax=1)
TNF_clustermap
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[46], line 7
#       5 # DEFNB_haps_table.iloc[:,[1,5:5012]]
#       6 TNF_haps_table_for_clustmap = TNF_haps_table.iloc[:,select_columns]
# ----> 7 TNF_clustermap = sb.clustermap(TNF_haps_table_for_clustmap,vmin=0,vmax=1)
#       8 TNF_clustermap
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
# ...
